# %% [markdown]
# # Feature Engineering - Attributes dataset

# %%
import pandas as pd
from datetime import datetime

# %%
# load attributes and sessions
attr = pd.read_pickle("data/LeanPlum/attr.pkl")
session = pd.read_pickle("data/LeanPlum/session.pkl")
session.head()

# %%
# load mapping of user_id_hash to user_id
users = pd.read_csv('data/user_dict.csv', header=None)
user_dict = {row[1][0]:int(row[1][1]) for row in users.iterrows()}

# %%
attr['user_id'] = attr['user_id_hash'].map(user_dict)
attr = attr.dropna(subset=['user_id'])\
    .drop('user_id_hash', axis=1)
attr['user_id'] = attr['user_id'].astype(int)
attr = attr.set_index('session_id')
attr.head()
# Out:
#                      attr_0  attr_1  attr_2    attr_3  \
# session_id
# 2662933751290886254     NaN     NaN     NaN  0.029999
# 5793726669394503241     NaN     NaN     NaN  0.000000
# 6545122651035219326     0.0     0.0     0.0  0.059998
# 2302333863698307661     0.0     0.0     0.0  0.000000
# 215362132811035045      0.0     0.0     0.0  0.000000
#
#                                                attr_4  attr_5  \
# session_id
# 2662933751290886254    romance_the_royal_romance_01:3     3.0
# 5793726669394503241    romance_the_royal_romance_01:2     2.0
# 6545122651035219326    romance_the_royal_romance_01:6     6.0
# 2302333863698307661  romance_rules_of_engagement_01:1     0.0
# 215362132811035045     romance_high_school_story_01:2     1.0
#
#                                              attr_6  attr_7  attr_8  \
# session_id
# 2662933751290886254  romance_the_royal_romance_01:3     NaN     3.0
# 5793726669394503241  romance_the_royal_romance_01:2     NaN     2.0
# 6545122651035219326  romance_the_royal_romance_01:6     1.0     6.0
# 2302333863698307661                             NaN     4.0     0.0
# 215362132811035045   romance_high_school_story_01:1     1.0     1.0
#
#                                              attr_9  ...  \
# session_id                                           ...
# 2662933751290886254                            None  ...
# 5793726669394503241                            None  ...
# 6545122651035219326  romance_the_royal_romance_01:1  ...
# 2302333863698307661                             NaN  ...
# 215362132811035045   romance_high_school_story_01:1  ...
#
#                                        attr_20 attr_22 attr_23  attr_24  \
# session_id
# 2662933751290886254                       None    None    None      NaN
# 5793726669394503241                       None    None    None      NaN
# 6545122651035219326  picker ya_romance_vampire     NaN    None      0.0
# 2302333863698307661  picker ya_romance_vampire     NaN    None      NaN
# 215362132811035045   picker ya_romance_vampire     NaN    None      NaN
#
#                      attr_25  attr_26  attr_27  attr_28  attr_29  user_id
# session_id
# 2662933751290886254      2.0      NaN      2.0      NaN      NaN   550123
# 5793726669394503241      0.0      NaN      0.0      NaN      NaN   550123
# 6545122651035219326      5.0      0.0      5.0      1.0      NaN   550123
# 2302333863698307661      0.0      0.0      0.0      1.0      NaN    54564
# 215362132811035045       0.0      0.0      0.0      1.0      NaN    96049
#
# [5 rows x 30 columns]

# %%
# join attributes with with sessions on session_id to get timestamp
session = session[['session_id', 'session_index', 'start_timestamp']].set_index('session_id')
attr2 = attr.join(session)

# %%
print(sum(attr2['session_index'].isna()))
print(len(attr2))
# Out:
# 561699
# 3945208

# %%
# drop rows that don't have a corresponding session index
attr_pred = attr2.dropna(subset=['session_index'])

# %%
# split into train and test (predict) based on timestamp
attr_pred['datetime'] = attr_pred['start_timestamp']\
                        .apply(lambda x:datetime.fromtimestamp(x/1000))
attr_train = attr_pred.loc[attr_pred.datetime < '2018-12-01']
# Out:
# /Users/evan/anaconda3/envs/ml/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# compute mean attribute for each user_id
attr_pred2 = attr_pred.groupby('user_id').mean()
attr_train2 = attr_train.groupby('user_id').mean()
attr_train2.head()
# Out:
#          attr_0  attr_1  attr_2    attr_3    attr_5  attr_7    attr_8  \
# user_id
# 0           0.0     0.0     0.0  0.029999  3.000000     2.0  3.000000
# 1           0.0     0.0     0.0  0.005001  2.333984     2.0  2.333984
# 2           NaN     NaN     NaN  0.029999  5.800781     1.5  5.800781
# 3           0.0     0.0     0.0  0.000000  1.000000     1.0  1.000000
# 4           0.0     0.0     0.0  0.000000  0.000000     1.0  0.000000
#
#          attr_10  attr_13   attr_14  ...  attr_18  attr_19  attr_24  attr_25  \
# user_id                              ...
# 0            0.0      0.0  2.000000  ...      0.0      0.0      NaN     2.00
# 1            0.0      0.0  2.333984  ...      0.5      1.0      1.0     0.50
# 2            NaN      NaN  0.000000  ...      0.5      2.0      NaN     2.25
# 3            0.0      0.0  2.000000  ...      0.0      2.0      NaN     0.00
# 4            0.0      0.0  0.000000  ...      0.0      2.0      NaN     0.00
#
#          attr_26  attr_27  attr_28  attr_29  session_index  start_timestamp
# user_id
# 0            0.0     2.00      1.0      NaN           1.00     1.540292e+12
# 1            0.0     0.50      1.0      NaN           3.75     1.541099e+12
# 2            0.0     2.25      1.0      NaN           4.50     1.541314e+12
# 3            0.0     0.00      1.0      NaN           1.00     1.542540e+12
# 4            0.0     0.00      1.0      NaN           2.00     1.543090e+12
#
# [5 rows x 23 columns]

# %%
# join attributes features with labels and compute correlation with target
labels14 = pd.read_csv('labels14.csv').set_index('user_id')
attr_train3 = labels14.join(attr_train2)
attr_train3 = attr_train3.fillna(0)
corr = attr_train3.corr()
corr.style.background_gradient()
# Out:
# /Users/evan/anaconda3/envs/ml/lib/python3.6/site-packages/numpy/core/_methods.py:32: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial)
# /Users/evan/anaconda3/envs/ml/lib/python3.6/site-packages/numpy/core/_methods.py:28: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial)
# /Users/evan/anaconda3/envs/ml/lib/python3.6/site-packages/matplotlib/colors.py:512: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col11 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col13 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col14 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col15 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col16 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col17 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col18 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col19 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col20 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col21 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col22 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row0_col23 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col11 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col13 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col14 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col15 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col16 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col17 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col18 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col19 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col20 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col21 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col22 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row1_col23 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row2_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row2_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row2_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row2_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row2_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row2_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row2_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e4ed4630_49ff_11e9_833a_6a000346ee60row2_col11 {
#             background-color:  #fff7fb;

# %%
# select best attributes only
attr_lst = ['attr_0', 'attr_1', 'attr_2', 'attr_3',
            'attr_5', 'attr_7', 'attr_8', 'attr_13',
            'attr_14', 'attr_15', 'attr_24', 'attr_25',
            'attr_27']
attr_train3 = attr_train3[attr_lst]
attr_pred3 = attr_pred2[attr_lst]

# %%
attr_train3 = attr_train3.fillna(0)
attr_pred3 = attr_pred3.fillna(0)

# %%
attr_pred3.head()
# Out:
#          attr_0  attr_1  attr_2    attr_3    attr_5  attr_7    attr_8  \
# user_id
# 0           0.0     0.0     0.0  0.029999  3.000000     2.0  3.000000
# 1           0.0     0.0     0.0  0.005001  2.333984     2.0  2.333984
# 2           0.0     0.0     0.0  0.029999  5.800781     1.5  5.800781
# 3           0.0     0.0     0.0  0.000000  1.000000     1.0  1.000000
# 4           0.0     0.0     0.0  0.000000  0.000000     1.0  0.000000
#
#          attr_13   attr_14  attr_15  attr_24  attr_25  attr_27
# user_id
# 0            0.0  2.000000      0.0      0.0     2.00     2.00
# 1            0.0  2.333984      0.5      1.0     0.50     0.50
# 2            0.0  0.000000      0.0      0.0     2.25     2.25
# 3            0.0  2.000000      0.0      0.0     0.00     0.00
# 4            0.0  0.000000      0.0      0.0     0.00     0.00

# %%
# create a dummy df with all user_ids and then join with attributes features
dummy = pd.DataFrame({'user_id': list(user_dict.values()), 'dummy': [0 for _ in range(len(user_dict.values()))]})
attr_features_full = dummy.join(attr_pred3).drop(axis=1, columns='dummy').fillna(value=0)
attr_features_full.head()
# Out:
#    user_id  attr_0  attr_1  attr_2    attr_3    attr_5  attr_7    attr_8  \
# 0        0     0.0     0.0     0.0  0.029999  3.000000     2.0  3.000000
# 1        1     0.0     0.0     0.0  0.005001  2.333984     2.0  2.333984
# 2        2     0.0     0.0     0.0  0.029999  5.800781     1.5  5.800781
# 3        3     0.0     0.0     0.0  0.000000  1.000000     1.0  1.000000
# 4        4     0.0     0.0     0.0  0.000000  0.000000     1.0  0.000000
#
#    attr_13   attr_14  attr_15  attr_24  attr_25  attr_27
# 0      0.0  2.000000      0.0      0.0     2.00     2.00
# 1      0.0  2.333984      0.5      1.0     0.50     0.50
# 2      0.0  0.000000      0.0      0.0     2.25     2.25
# 3      0.0  2.000000      0.0      0.0     0.00     0.00
# 4      0.0  0.000000      0.0      0.0     0.00     0.00

# %%
attr_features_full.to_csv(path_or_buf='features_attr3_full.csv', index=False)

# %%
attr_train3.reset_index().to_csv(path_or_buf='features_attr3.csv', index=False)
